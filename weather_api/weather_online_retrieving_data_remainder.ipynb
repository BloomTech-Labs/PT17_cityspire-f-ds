# %%
from wwo_hist import retrieve_hist_data
import pandas as pd
import os
import os.path
import regex

# Loading original data set 

FILE_PATH = os.path.abspath(os.path.dirname('other_data/final.csv'))
cities = pd.read_csv(FILE_PATH + '/final.csv')
cities.replace('\s+', '_',regex=True,inplace=True)
cities
# Out:
#             City State  TotalPop     Men   Women  Hispanic  White  Black  \
# 0          Akron    OH    267782  129623  138086       1.9   67.4   23.2
# 1         Albany    GA     93421   43571   49835       2.8   29.2   65.2
# 2         Albany    NY    147794   70664   77096       7.8   60.3   20.1
# 3         Albany    OR     61555   30378   31168      11.4   82.7    0.6
# 4    Albuquerque    NM    632240  309415  322758      50.4   38.5    2.5
# ..           ...   ...       ...     ...     ...       ...    ...    ...
# 392    Worcester    MA    183628   89977   93611      20.8   57.2   11.7
# 393      Wyoming    MI     56377   27516   28855      23.8   62.0    7.1
# 394       Yakima    WA    125036   61639   63374      40.1   54.1    0.9
# 395    Yuba_City    CA     75848   37647   38198      28.2   46.2    2.1
# 396         Yuma    AZ    142402   73123   69270      52.5   40.9    2.4
#
#      Native  Asian  ...  Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# ...

# %%
cities_city = cities[['City', 'State']]

# %%
cities_city = cities_city.drop_duplicates()
cities_city
# Out:
#             City State
# 0          Akron    OH
# 1         Albany    GA
# 2         Albany    NY
# 3         Albany    OR
# 4    Albuquerque    NM
# ..           ...   ...
# 392    Worcester    MA
# 393      Wyoming    MI
# 394       Yakima    WA
# 395    Yuba_City    CA
# 396         Yuma    AZ
#
# [397 rows x 2 columns]

# %%
# Convert 'city' column to a list to feed into the function that calls API 
cities_list_total = cities_city['City'].tolist()
cities_list_total.sort(reverse=False)
cities_list_total
# Out:
# ['Akron',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albuquerque',
#  'Alexandria',
#  'Allentown',
#  'Altoona',
#  'Amarillo',
#  'Anacortes',
#  'Anaheim',
#  'Anchorage',
#  'Anderson',
#  'Ann_Arbor',
#  'Appleton',
#  'Arlington',
#  'Arroyo_Grande',
#  'Asheville',
#  'Ashland',
#  'Ashland',
#  'Athens',
#  'Atlantic_City',
#  'Auburn',
#  'Aurora',
#  'Austin',
#  'Bakersfield',
#  'Baltimore',
#  'Bangor',
#  'Baton_Rouge',
#  'Bay_City',
#  'Beaumont',
#  'Bellevue',
#  'Bellingham',
#  'Beloit',
#  'Bend',
#  'Benton_Harbor',
#  'Billings',
#  'Biloxi',
#  'Bismarck',
#  'Blacksburg',
#  'Bloomington',
#  'Bossier_City',
#  'Boston',
#  'Boulder',
#  'Bowling_Green',
#  'Bradenton',
#  'Bremerton',
#  'Bridgeport',
#  'Bridgeton',
#  'Bristol',
#  'Brookings',
#  'Brownsville',
#  'Bryan',
#  'Buffalo',
#  'Burlington',
#  'Cambridge',
#  'Canton',
#  'Cape_Coral',
#  'Carlsbad',
#  'Carmel',
#  'Casper',
#  'Cedar_Rapids',
#  'Chambersburg',
#  'Champaign',
# ...

# %%
FILE_PATH = os.path.abspath(os.path.dirname('merged_cities.csv'))
cities_df = pd.read_csv(FILE_PATH + '/merged_cities.csv')
cities_df
# Out:
#                   date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0       2018-01-01 00:00:00         1        -4           0.0     10.0
# 1       2018-01-01 03:00:00         1        -4           0.0     10.0
# 2       2018-01-01 06:00:00         1        -4           0.0     10.0
# 3       2018-01-01 09:00:00         1        -4           0.0     10.0
# 4       2018-01-01 12:00:00         1        -4           0.0     10.0
# ...                     ...       ...       ...           ...      ...
# 818475  2021-02-28 09:00:00        10         2           0.0     11.2
# 818476  2021-02-28 12:00:00        10         2           0.0     11.2
# 818477  2021-02-28 15:00:00        10         2           0.0     11.2
# 818478  2021-02-28 18:00:00        10         2           0.0     11.2
# 818479  2021-02-28 21:00:00        10         2           0.0     11.2
#
#         uvIndex  moon_illumination  moonrise   moonset   sunrise  ...  \
# ...

# %%
cities_location = cities_df[['location', 'date_time']]

# %%
cities_location = cities_location['location'].drop_duplicates()
cities_location
# Out:
# 0              Austin
# 9240            Provo
# 18480         Concord
# 27720          Queens
# 36960       Charlotte
#              ...
# 760600        Detroit
# 772760    Albuquerque
# 782000         Boston
# 794160    Minneapolis
# 806320      Las_Vegas
# Name: location, Length: 87, dtype: object

# %%
# Convert 'city' column to a list to feed into the function that calls API 
cities_done = cities_location.tolist()
cities_done.sort(reverse=False)
cities_done
# Out:
# ['Akron',
#  'Albany',
#  'Albuquerque',
#  'Allentown',
#  'Atlanta',
#  'Austin',
#  'Bakersfield',
#  'Baltimore',
#  'Baton_Rouge',
#  'Birmingham',
#  'Boston',
#  'Bridgeport',
#  'Bronx',
#  'Brooklyn',
#  'Buffalo',
#  'Cape_Coral',
#  'Charleston',
#  'Charlotte',
#  'Chicago',
#  'Cincinnati',
#  'Cleveland',
#  'Colorado_Springs',
#  'Columbia',
#  'Columbus',
#  'Concord',
#  'Dallas',
#  'Dayton',
#  'Denver',
#  'Detroit',
#  'El_Paso',
#  'Fort_Worth',
#  'Fresno',
#  'Grand_Rapids',
#  'Hartford',
#  'Honolulu',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'Kansas_City',
#  'Knoxville',
#  'Las-Vegas',
#  'Las_Vegas',
#  'Los_Angeles',
#  'Louisville',
#  'Manhattan',
#  'McAllen',
#  'Memphis',
#  'Mesa',
#  'Miami',
#  'Milwaukee',
#  'Minneapolis',
#  'Mission_Viejo',
#  'Nashville',
#  'New_Haven',
#  'New_Orleans',
#  'New_York',
#  'Ogden',
#  'Oklahoma_City',
#  'Omaha',
#  'Orlando',
#  'Palm_Bay',
#  'Philadelphia',
#  'Phoenix',
#  'Pittsburgh',
# ...

# %%
def Diff(li1, li2):
    return (list(list(set(cities_list_total)-set(cities_done)) + list(set(cities_done)-set(cities_list_total))))

# %%
Diff(cities_list_total, cities_done)
# Out:
# ['Modesto',
#  'Greeley',
#  'Fort_Smith',
#  'Grants_Pass',
#  'Rock_Island',
#  'Fairfield',
#  'Gainesville',
#  'Richland',
#  'Urbana',
#  'Christiansburg',
#  'Monroe',
#  'Evansville',
#  'Muscatine',
#  'Trenton',
#  'Rome',
#  'Myrtle_Beach',
#  'Lodi',
#  'Greenville',
#  'Ormond_Beach',
#  'Hillsboro',
#  'Missoula',
#  'Odessa',
#  'Ocala',
#  'Blacksburg',
#  'Sebastian',
#  'Salisbury',
#  'Yuba_City',
#  'Clearfield',
#  'Bend',
#  'Indiana',
#  'Dover',
#  'Waco',
#  'Atlantic_City',
#  'Fairbanks',
#  'Harrisburg',
#  'Portage',
#  'Decatur',
#  'Florence',
#  'Roseville',
#  'Panama_City',
#  'Bangor',
#  'Stockton',
#  'Hanford',
#  'Elyria',
#  'Los_Alamos',
#  'Bradenton',
#  'Cheyenne',
#  'Fayetteville',
#  'Joplin',
#  'Ashland',
#  'Temple',
#  'Ithaca',
#  'Rocky_Mount',
#  'Bismarck',
#  'Pueblo',
#  'Sunnyvale',
#  'Thousand_Oaks',
#  'Clinton',
#  'North_Little_Rock',
#  'Kingsport',
#  'Niagara_Falls',
#  'Massillon',
#  'West_Palm_Beach',
#  'Naples',
# ...
